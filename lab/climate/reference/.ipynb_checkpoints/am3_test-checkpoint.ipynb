# %% [markdown]
# # Liby's Test on `am3`

# %%
# %matplotlib inline 
from mpl_toolkits.basemap import Basemap # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
from netCDF4 import Dataset, num2date  # netcdf4-python module

# %%
ds = Dataset('../data/GFDL_am3_cli_2009_01.nc')
ds
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     dimensions(sizes): lonDim(144), latDim(91), plevDim(40), timeDim(1)
#     variables(dimensions): float64 lon(lonDim), float64 lat(latDim), float64 plev(plevDim), float64 time(timeDim), float32 cli(plevDim,latDim,lonDim)
#     groups:

# %%
plevs = ds.variables["plev"]
plevs
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float64 plev(plevDim)
#     units: hPa
# unlimited dimensions:
# current shape = (40,)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
plevs[:]
# Out:
# masked_array(data=[1004.22 ,  989.009,  973.755,  958.501,  943.247,
#                     927.994,  912.741,  897.488,  882.236,  866.984,
#                     850.732,  836.481,  818.689,  795.814,  770.398,
#                     744.984,  719.574,  694.163,  662.403,  624.298,
#                     586.197,  548.105,  500.023,  471.952,  433.897,
#                     395.862,  357.85 ,  315.844,  267.025,  226.723,
#                     215.583,  177.661,  147.115,  121.25 ,  100.514,
#                      83.439,   67.45 ,   48.282,   34.272,   24.08 ],
#              mask=False,
#        fill_value=1e+20)

# %%
clis = ds.variables["cli"]
clis
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 cli(plevDim, latDim, lonDim)
#     _FillValue: -999.0
#     units: kg/kg
# unlimited dimensions:
# current shape = (40, 91, 144)
# filling on

# %%
cli_at_plev_150 = clis[-8, :, :]
print(cli_at_plev_150)
print(cli_at_plev_150.shape)
maximum = cli_at_plev_150.max()
minimum = cli_at_plev_150.min()
print("max: %f, min: %f" % (maximum, minimum))
# Out:
# [[9.3911016e-12 9.3911016e-12 9.3911016e-12 ... 9.3911016e-12
#   9.3911016e-12 9.3911016e-12]
#  [5.1431911e-11 5.1191315e-11 5.0935929e-11 ... 5.2074251e-11
#   5.1872485e-11 5.1658667e-11]
#  [3.6522417e-11 3.6725761e-11 3.6940506e-11 ... 3.5979119e-11
#   3.6149264e-11 3.6330307e-11]
#  ...
#  [1.9848936e-10 1.9553147e-10 1.9265135e-10 ... 2.0770489e-10
#   2.0458811e-10 2.0151233e-10]
#  [3.6352199e-11 4.1097258e-11 4.5842316e-11 ... 2.2117030e-11
#   2.6862087e-11 3.1607141e-11]
#  [2.4383121e-10 2.4383121e-10 2.4383121e-10 ... 2.4383121e-10
#   2.4383121e-10 2.4383121e-10]]
# (91, 144)
# max: 0.000245, min: -0.000002

# %%
lats = ds.variables['lat'][:]
lons = ds.variables['lon'][:]
lons, lats = np.meshgrid(lons - 180, lats)

# %%
fig = plt.figure(figsize=(12, 12))
m = Basemap()
m.drawcoastlines()
x, y = m(lons, lats)
cs = m.contourf(x, y, cli_at_plev_150, np.arange(minimum, maximum, 0.000001), cmap=plt.cm.jet)
cb = m.colorbar(cs)
